# %%
import pandas as pd

# %%
import os
print(os.getcwd())
df = pd.read_csv(r"C:\Users\bhath\OneDrive\Documents\Coding\complete-pandas-tutorial\datasets\employees.csv")
print(df)
# Out:
# c:\Users\bhath\OneDrive\Documents\Coding\complete-pandas-tutorial\notebook
#    EmployeeID     Name Department  Salary JoiningDate
# 0         101    Alice         HR   60000  2018-03-15
# 1         102      Bob         IT   75000  2019-07-23
# 2         103  Charlie    Finance   80000  2020-01-10
# 3         104    David         IT   72000  2021-05-18
# 4         105      Eva         HR   65000  2020-11-01
